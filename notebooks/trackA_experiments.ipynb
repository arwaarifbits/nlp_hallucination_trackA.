# %%
# !git clone https://github.com/arwaarifbits/nlp_hallucination_trackA..git
# Out:
# Cloning into 'nlp_hallucination_trackA.'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 17 (delta 1), reused 17 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (17/17), 4.04 KiB | 4.04 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd nlp_hallucination_trackA.
# Out:
# /content/nlp_hallucination_trackA./nlp_hallucination_trackA.

# %%
# !pip install transformers torch huggingface_hub

# %%
import os
HF_TOKEN = os.getenv("HF_TOKEN")

# %%
from src.model_utils import load_model, get_logits

tokenizer, model = load_model()

prompt = "What is the capital of France?"
context = "France is a country in Europe. Its capital is Paris."

logits = get_logits(prompt, tokenizer, model, context)

print("Logits shape:", logits.shape)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Loading model meta-llama/Llama-3.2-1B on cuda...
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Model loaded successfully!
# Logits shape: torch.Size([1, 20, 128256])

# %%
import pandas as pd

data = {
    "prompt": prompt,
    "context": context,
    "logits_shape": str(logits.shape)
}

df = pd.DataFrame([data])

df.to_csv("results/test_output.csv", index=False)

# %%
# !git config --global user.email "p20250410@dubai.bits-pilani.ac.in"
# !git config --global user.name "arwaarifbits"

# !git add .
# !git commit -m "Added experiment results"
# !git push
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 490 bytes | 490.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/arwaarifbits/nlp_hallucination_trackA..git
#    7de9587..797fe5f  main -> main

# %%
# !git add -f results/
# !git commit -m "Force add new experiment results"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
